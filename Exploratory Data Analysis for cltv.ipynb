# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cltv=pd.read_csv('Insurance_Marketing-Customer-Value-Analysis.csv')

# %%
cltv.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0         2/24/2011         Employed      F   56274  ...
# 1         1/31/2011       Unemployed      F       0  ...
# 2         2/19/2011         Employed      F   48767  ...
# 3         1/20/2011       Unemployed      M       0  ...
# 4          2/3/2011         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
cltv.drop(['Customer','Effective To Date'],axis=1,inplace=True)

# %%
cltv.columns
# Out:
# Index(['State', 'Customer Lifetime Value', 'Response', 'Coverage', 'Education',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
cltv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 22 columns):
# State                            9134 non-null object
# Customer Lifetime Value          9134 non-null float64
# Response                         9134 non-null object
# Coverage                         9134 non-null object
# Education                        9134 non-null object
# EmploymentStatus                 9134 non-null object
# Gender                           9134 non-null object
# Income                           9134 non-null int64
# Location Code                    9134 non-null object
# Marital Status                   9134 non-null object
# Monthly Premium Auto             9134 non-null int64
# Months Since Last Claim          9134 non-null int64
# Months Since Policy Inception    9134 non-null int64
# Number of Open Complaints        9134 non-null int64
# Number of Policies               9134 non-null int64
# ...

# %%
cltv.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Uni Varient Analysis

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# #### State

# %%
sns.countplot(cltv['State'])

# %% [markdown]
# #### Response

# %%
sns.countplot(cltv['Response'])

# %% [markdown]
# #### Coverage

# %%
sns.countplot(cltv['Coverage'])

# %% [markdown]
# #### Education

# %%
sns.countplot(cltv['Education'])

# %% [markdown]
# #### EmploymentStatus

# %%
sns.countplot(cltv['EmploymentStatus'])

# %% [markdown]
# #### Gender

# %%
sns.countplot(cltv['Gender'])

# %% [markdown]
# #### Location Code

# %%
sns.countplot(cltv['Location Code'])

# %% [markdown]
# #### Marital Status

# %%
sns.countplot(cltv['Marital Status'])

# %% [markdown]
# #### Policy Type

# %%
sns.countplot(cltv['Policy Type'])

# %% [markdown]
# #### Policy

# %%
sns.countplot(cltv['Policy'])

# %% [markdown]
# #### Renew Offer Type

# %%
sns.countplot(cltv['Renew Offer Type'])

# %% [markdown]
# #### Sales Channel

# %%
sns.countplot(cltv['Sales Channel'])

# %% [markdown]
# #### Vehicle Size

# %%
sns.countplot(cltv['Vehicle Size'])

# %% [markdown]
# #### Vehicle Class

# %%
sns.countplot(cltv['Vehicle Class'])

# %% [markdown]
# ### Continous Variables

# %% [markdown]
# #### Customer Lifetime Value

# %%
sns.distplot(cltv['Customer Lifetime Value'])

# %%
sns.boxplot(cltv['Customer Lifetime Value'])
plt.show()

# %% [markdown]
# #### Income

# %%
sns.distplot(cltv['Income'])

# %%
sns.boxplot(cltv['Income'])

# %% [markdown]
# #### Monthly Premium Auto

# %%
sns.distplot(cltv['Monthly Premium Auto'])

# %%
sns.boxplot(cltv['Monthly Premium Auto'])

# %% [markdown]
# #### Months Since Last Claim

# %%
sns.distplot(cltv['Months Since Last Claim'])

# %%
sns.boxplot(cltv['Months Since Last Claim'])

# %% [markdown]
# #### Months Since Policy Inception

# %%
sns.distplot(cltv['Months Since Policy Inception'])

# %%
sns.boxplot(cltv['Months Since Policy Inception'])

# %% [markdown]
# #### Number of Open Complaints

# %%
sns.distplot(cltv['Number of Open Complaints'])

# %%
sns.boxplot(cltv['Number of Open Complaints'])

# %% [markdown]
# #### Number of Policies

# %%
sns.distplot(cltv['Number of Policies'])

# %%
sns.boxplot(cltv['Number of Policies'])

# %% [markdown]
# #### Total Claim Amount

# %%
sns.distplot(cltv['Total Claim Amount'])

# %%
sns.boxplot(cltv['Total Claim Amount'])

# %% [markdown]
# ## Bi Varient Analysis

# %% [markdown]
# ### Continous Variable vs Continous Variable

# %% [markdown]
# #### Customer Lifetime Value vs Income

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Income'])

# %% [markdown]
# #### Customer Lifetime Value vs Monthly Premium Auto

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Monthly Premium Auto'])

# %% [markdown]
# #### Customer Lifetime Value vs Months Since Last Claim

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Months Since Last Claim'])

# %% [markdown]
# #### Customer Lifetime Value vs Months Since Policy Inception

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Months Since Policy Inception'])

# %% [markdown]
# #### Customer Lifetime Value vs Number of Open Complaints

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Number of Open Complaints'])

# %% [markdown]
# #### Customer Lifetime Value vs Number of Policies

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Number of Policies'])

# %% [markdown]
# #### Customer Lifetime Value vs Total Claim Amount

# %%
sns.jointplot(cltv['Customer Lifetime Value'],cltv['Total Claim Amount'])

# %% [markdown]
# ### Continous variables vs Categorical variables

# %% [markdown]
# #### Customer Lifetime Value vs State

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['State'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['State']).agg('mean')
# Out:
# State
# Arizona       7861.341489
# California    8003.647758
# Nevada        8056.706839
# Oregon        8077.901191
# Washington    8021.472273
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Response

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Response'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Response']).agg('mean')
# Out:
# Response
# No     8030.022305
# Yes    7854.871361
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Coverage

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Coverage'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Coverage']).agg('mean')
# Out:
# Coverage
# Basic        7190.706422
# Extended     8789.677608
# Premium     10895.603083
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Education

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Education'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Education']).agg('mean')
# Out:
# Education
# Bachelor                7872.660412
# College                 7851.064644
# Doctor                  7520.344837
# High School or Below    8296.709033
# Master                  8243.484692
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs EmploymentStatus

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['EmploymentStatus'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['EmploymentStatus']).agg('mean')
# Out:
# EmploymentStatus
# Disabled         7847.889354
# Employed         8219.117754
# Medical Leave    7641.822437
# Retired          7487.865141
# Unemployed       7636.319761
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Gender

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Gender'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Gender']).agg('mean')
# Out:
# Gender
# F    8096.602370
# M    7909.551488
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Location Code

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Location Code'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Location Code']).agg('mean')
# Out:
# Location Code
# Rural       7953.699156
# Suburban    8004.457415
# Urban       8064.132929
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Marital Status

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Marital Status'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Marital Status']).agg('mean')
# Out:
# Marital Status
# Divorced    8241.239135
# Married     8078.966969
# Single      7714.837018
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Policy Type

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Policy Type'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Policy Type']).agg('mean')
# Out:
# Policy Type
# Corporate Auto    7814.409552
# Personal Auto     8027.363535
# Special Auto      8594.245038
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Policy

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Policy'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Policy']).agg('mean')
# Out:
# Policy
# Corporate L1    8474.928216
# Corporate L2    7597.695292
# Corporate L3    7707.721963
# Personal L1     7989.762020
# Personal L2     8054.909341
# Personal L3     8023.911602
# Special L1      8332.763207
# Special L2      8326.906361
# Special L3      9007.091956
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Renew Offer Type

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Renew Offer Type'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Renew Offer Type']).agg('mean')
# Out:
# Renew Offer Type
# Offer1    8707.085583
# Offer2    7396.753826
# Offer3    7997.886516
# Offer4    7179.947270
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Sales Channel

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Sales Channel'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Sales Channel']).agg('mean')
# Out:
# Sales Channel
# Agent          7957.709353
# Branch         8119.711861
# Call Center    8100.085753
# Web            7779.788057
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Vehicle Class

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Vehicle Class'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Vehicle Class']).agg('mean')
# Out:
# Vehicle Class
# Four-Door Car     6631.726607
# Luxury Car       17053.348399
# Luxury SUV       17122.999134
# SUV              10443.511816
# Sports Car       10750.989331
# Two-Door Car      6671.030732
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Customer Lifetime Value vs Vehicle Size

# %%
sns.barplot(cltv['Customer Lifetime Value'],cltv['Vehicle Size'])
plt.show()
cltv['Customer Lifetime Value'].groupby(cltv['Vehicle Size']).agg('mean')
# Out:
# Vehicle Size
# Large      7544.995730
# Medsize    8050.661755
# Small      8085.095932
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(cltv)

# %% [markdown]
# Heatmap

# %%
sns.heatmap(cltv.corr())
